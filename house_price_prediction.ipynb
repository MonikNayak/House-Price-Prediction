# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv("train.csv")
df
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0         Owner                   0     0        2       BHK  1300.236407
# 1        Dealer                   0     0        2       BHK  1275.000000
# 2         Owner                   0     0        2       BHK   933.159722
# 3         Owner                   0     1        2       BHK   929.921143
# 4        Dealer                   1     0        2       BHK   999.009247
# ...         ...                 ...   ...      ...       ...          ...
# 29446     Owner                   0     0        3       BHK  2500.000000
# 29447     Owner                   0     0        2       BHK   769.230769
# 29448    Dealer                   0     0        2       BHK  1022.641509
# 29449     Owner                   0     0        2       BHK   927.079009
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE                            ADDRESS  LONGITUDE  \
# ...

# %%
df.isnull().sum()
# Out:
# POSTED_BY                0
# UNDER_CONSTRUCTION       0
# RERA                     0
# BHK_NO.                  0
# BHK_OR_RK                0
# SQUARE_FT                0
# READY_TO_MOVE            0
# RESALE                   0
# ADDRESS                  0
# LONGITUDE                0
# LATITUDE                 0
# TARGET(PRICE_IN_LACS)    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 401

# %%
data=df.copy()
data
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0         Owner                   0     0        2       BHK  1300.236407
# 1        Dealer                   0     0        2       BHK  1275.000000
# 2         Owner                   0     0        2       BHK   933.159722
# 3         Owner                   0     1        2       BHK   929.921143
# 4        Dealer                   1     0        2       BHK   999.009247
# ...         ...                 ...   ...      ...       ...          ...
# 29446     Owner                   0     0        3       BHK  2500.000000
# 29447     Owner                   0     0        2       BHK   769.230769
# 29448    Dealer                   0     0        2       BHK  1022.641509
# 29449     Owner                   0     0        2       BHK   927.079009
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE                            ADDRESS  LONGITUDE  \
# ...

# %%
data.drop_duplicates(inplace=True)
data
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0         Owner                   0     0        2       BHK  1300.236407
# 1        Dealer                   0     0        2       BHK  1275.000000
# 2         Owner                   0     0        2       BHK   933.159722
# 3         Owner                   0     1        2       BHK   929.921143
# 4        Dealer                   1     0        2       BHK   999.009247
# ...         ...                 ...   ...      ...       ...          ...
# 29446     Owner                   0     0        3       BHK  2500.000000
# 29447     Owner                   0     0        2       BHK   769.230769
# 29448    Dealer                   0     0        2       BHK  1022.641509
# 29449     Owner                   0     0        2       BHK   927.079009
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE                            ADDRESS  LONGITUDE  \
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.describe()
# Out:
#        UNDER_CONSTRUCTION          RERA       BHK_NO.     SQUARE_FT  \
# count        29050.000000  29050.000000  29050.000000  2.905000e+04
# mean             0.178967      0.315869      2.390809  2.003171e+04
# std              0.383332      0.464869      0.880677  1.914411e+06
# min              0.000000      0.000000      1.000000  3.000000e+00
# 25%              0.000000      0.000000      2.000000  9.000000e+02
# 50%              0.000000      0.000000      2.000000  1.172742e+03
# 75%              0.000000      1.000000      3.000000  1.550169e+03
# max              1.000000      1.000000     20.000000  2.545455e+08
#
#        READY_TO_MOVE        RESALE     LONGITUDE      LATITUDE  \
# count   29050.000000  29050.000000  29050.000000  29050.000000
# mean        0.821033      0.930361     21.270272     76.829585
# std         0.383332      0.254541      6.195973     10.567572
# min         0.000000      0.000000    -37.713008   -121.761248
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29050 entries, 0 to 29450
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   POSTED_BY              29050 non-null  object
#  1   UNDER_CONSTRUCTION     29050 non-null  int64
#  2   RERA                   29050 non-null  int64
#  3   BHK_NO.                29050 non-null  int64
#  4   BHK_OR_RK              29050 non-null  object
#  5   SQUARE_FT              29050 non-null  float64
#  6   READY_TO_MOVE          29050 non-null  int64
#  7   RESALE                 29050 non-null  int64
#  8   ADDRESS                29050 non-null  object
#  9   LONGITUDE              29050 non-null  float64
#  10  LATITUDE               29050 non-null  float64
#  11  TARGET(PRICE_IN_LACS)  29050 non-null  float64
# dtypes: float64(4), int64(5), object(3)
# memory usage: 2.9+ MB

# %%
data1=data.drop(['POSTED_BY','BHK_OR_RK','ADDRESS'],axis=1)
data1
# Out:
#        UNDER_CONSTRUCTION  RERA  BHK_NO.    SQUARE_FT  READY_TO_MOVE  RESALE  \
# 0                       0     0        2  1300.236407              1       1
# 1                       0     0        2  1275.000000              1       1
# 2                       0     0        2   933.159722              1       1
# 3                       0     1        2   929.921143              1       1
# 4                       1     0        2   999.009247              0       1
# ...                   ...   ...      ...          ...            ...     ...
# 29446                   0     0        3  2500.000000              1       1
# 29447                   0     0        2   769.230769              1       1
# 29448                   0     0        2  1022.641509              1       1
# 29449                   0     0        2   927.079009              1       1
# 29450                   0     1        2   896.774194              1       1
#
# ...

# %%
data1.isnull().sum()
# Out:
# Unnamed: 0               0
# UNDER_CONSTRUCTION       0
# RERA                     0
# BHK_NO.                  0
# SQUARE_FT                0
# READY_TO_MOVE            0
# RESALE                   0
# LONGITUDE                0
# LATITUDE                 0
# TARGET(PRICE_IN_LACS)    0
# dtype: int64

# %%
x=data1.iloc[:,0:12]#leaving last column
y=data1.iloc[:,-1:]
x
# Out:
#        Unnamed: 0  UNDER_CONSTRUCTION  RERA  BHK_NO.    SQUARE_FT  \
# 0               0                   0     0        2  1300.236407
# 1               1                   0     0        2  1275.000000
# 2               2                   0     0        2   933.159722
# 3               3                   0     1        2   929.921143
# 4               4                   1     0        2   999.009247
# ...           ...                 ...   ...      ...          ...
# 29045       29446                   0     0        3  2500.000000
# 29046       29447                   0     0        2   769.230769
# 29047       29448                   0     0        2  1022.641509
# 29048       29449                   0     0        2   927.079009
# 29049       29450                   0     1        2   896.774194
#
#        READY_TO_MOVE  RESALE  LONGITUDE   LATITUDE  TARGET(PRICE_IN_LACS)
# 0                  1       1  12.969910  77.597960                   55.0
# ...

# %%
y
# Out:
#        TARGET(PRICE_IN_LACS)
# 0                       55.0
# 1                       51.0
# 2                       43.0
# 3                       62.5
# 4                       60.5
# ...                      ...
# 29045                   45.0
# 29046                   16.0
# 29047                   27.1
# 29048                   67.0
# 29049                   27.8
#
# [29050 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.10,random_state=20)
x_train
# Out:
#        Unnamed: 0  UNDER_CONSTRUCTION  RERA  BHK_NO.     SQUARE_FT  \
# 10453       10499                   0     0        2   1060.284762
# 20013       20225                   0     0        1    460.122699
# 12672       12746                   0     0        3   1449.875725
# 16295       16429                   0     0       15  15001.153930
# 5725         5739                   0     1        1    564.844103
# ...           ...                 ...   ...      ...           ...
# 23452       23728                   0     1        2   1090.116279
# 23775       24061                   0     0        3   3520.261973
# 4367         4375                   0     0        2    891.265597
# 27098       27449                   1     0        2   1172.256594
# 15715       15840                   1     1        1    494.595480
#
#        READY_TO_MOVE  RESALE  LONGITUDE   LATITUDE  TARGET(PRICE_IN_LACS)
# 10453              1       1  28.666670  77.416670                   35.0
# ...

# %%
from sklearn.linear_model import LinearRegression
regression=LinearRegression()
regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(regression,x_train,y_train,scoring="neg_mean_squared_error",cv=10)
mse=cross_val_score(regression,x_train,y_train,scoring="neg_mean_squared_error",cv=10)

# %%
import numpy as np
np.mean(mse)
# Out:
# -1.0046543945677376e-24

# %%
reg_pred=regression.predict(x_test)
reg_pred
# Out:
# array([[  71.99038923],
#        [  64.69825797],
#        [  49.66753844],
#        ...,
#        [  35.45532343],
#        [  54.13210859],
#        [1258.82195629]])

# %%
import seaborn as sns
sns.displot(reg_pred-y_test,kind='kde')

# %%
from sklearn.metrics import r2_score
score=r2_score(reg_pred,y_test)
score
# Out:
# 0.8810330970716177

# %%
bhk=[1,2,3]
bhkct=[data1[data1['BHK_NO.']==1].index.size,data1[data1['BHK_NO.']==2].index.size,data1[data1['BHK_NO.']==3].index.size]
plt.bar(bhk,bhkct,color=['orange','red','yellow'])#showing 1bhk properites ,2bhk and 3bhk
plt.xlabel("number of bhk")
plt.ylabel("number of properties")
# Out:
# Text(0, 0.5, 'number of properties')

# %%
u=data1[data1['UNDER_CONSTRUCTION']==0].index.size
nu=data1[data1['UNDER_CONSTRUCTION']==1].index.size
undercone=[u,nu]
plt.figure(figsize=(4,4))
plt.pie(undercone,labels=['under construction\n'+str(u),'not under construction\n'+str(nu)])#showing how many underconstruction and how many are not
# Out:
# ([<matplotlib.patches.Wedge at 0x1d21314e150>,
# ...
#  [Text(-0.9292118415875994, 0.5886980154997825, 'under construction\n24157'),
#   Text(0.9292118140286553, -0.5886980589993277, 'not under construction\n5294')])
